# %% [markdown]
# # MIT Critical Data: CDC County level COVID Data

# %% [markdown]
# <!-- **TEAM ID:** Team 15
#
# **SEMESTER:** 4th
#
# **DIVISION:** D
#
# **DEPARTMENT:** Computer Science
#
# **TITLE ID:** 4DEDA_CP_05 -->
#
# ## Problem Statement
# >**We had experienced COVID crises that arised at it's peak during early 2020. Many families had lost their good one's due to this pandemic.With the MIT Critical Data,we have to do monthly and yearly analysis during which death rates and recovery rates were maximum along with COVID infected people .**
#
# <!-- #### TEAM LEADER AND MEMBERS: -->

# %%
df = pd.read_csv('C:\\Users\\LENOVO\\OneDrive\\Documents\\details.csv')
df=df.drop(4)
df
# Out:
#         Team Members           USN  Roll No.
# 0       Abhay Shirol   01fe20bc240     456.0
# 1   Sanjeevini S. G.  01fe20bcs225     441.0
# 2  Moeez  Khan A. T.  01fe21bcs415     464.0
# 3   Vaishnavi Torgal  01fe20bcs224     440.0

# %%
#Importing all the library files
import seaborn as sns
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load all the CSV files

# %%
#Reading a CSV file
df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Jan/01-01-2021.csv')
df
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2021-01-02 05:30:44  32.3182
# 1                     Alaska             US  2021-01-02 05:30:44  61.3707
# 2             American Samoa             US  2021-01-02 05:30:44 -14.2710
# 3                    Arizona             US  2021-01-02 05:30:44  33.7298
# 4                   Arkansas             US  2021-01-02 05:30:44  34.9697
# 5                 California             US  2021-01-02 05:30:44  36.1162
# 6                   Colorado             US  2021-01-02 05:30:44  39.0598
# 7                Connecticut             US  2021-01-02 05:30:44  41.5978
# 8                   Delaware             US  2021-01-02 05:30:44  39.3185
# 9           Diamond Princess             US  2021-01-02 05:30:44      NaN
# 10      District of Columbia             US  2021-01-02 05:30:44  38.8974
# 11                   Florida             US  2021-01-02 05:30:44  27.7663
# ...

# %%
#Listing all the csv files in a particular folder
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Jan')]
print(*filenames, sep='\n')
# Out:
# 01-01-2021.csv
# 01-02-2021.csv
# 01-03-2021.csv
# 01-04-2021.csv
# 01-05-2021.csv
# 01-06-2021.csv
# 01-07-2021.csv
# 01-08-2021.csv
# 01-09-2021.csv
# 01-10-2021.csv
# 01-11-2021.csv
# 01-12-2021.csv
# 01-13-2021.csv
# 01-14-2021.csv
# 01-15-2021.csv
# 01-16-2021.csv
# 01-17-2021.csv
# 01-18-2021.csv
# 01-19-2021.csv
# 01-20-2021.csv
# 01-21-2021.csv
# 01-22-2021.csv
# 01-23-2021.csv
# 01-24-2021.csv
# 01-25-2021.csv
# 01-26-2021.csv
# 01-27-2021.csv
# 01-28-2021.csv
# 01-29-2021.csv
# 01-30-2021.csv
# 01-31-2021.csv

# %% [markdown]
# ### Concatenating all the day-wise CSV files into one Month-wise file

# %%
#Concatenating all january 2021 files
jan = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Jan/'+file)
    jan = pd.concat([jan, df])

jan

# Saving all_data to a CSV file
jan.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/JAN21.csv', index=False)

# %%
#concatenating all february 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Feb')]
feb = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Feb/'+file)
    feb = pd.concat([feb, df])

feb

# Saving all_data to a CSV file
feb.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/FEB21.csv', index=False)

# %%
#concatenating all march 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Mar')]
mar = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Mar/'+file)
    mar = pd.concat([mar, df])

mar

# Saving all_data to a CSV file
mar.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/MAR21.csv', index=False)

# %%
#concatenating all april 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Apr')]
apr = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Apr/'+file)
    apr = pd.concat([apr, df])

apr

# Saving all_data to a CSV file
apr.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/APR21.csv', index=False)

# %%
#concatenating all may 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/May')]
may = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/May/'+file)
    may = pd.concat([may, df])

may

# Saving all_data to a CSV file
may.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/MAY21.csv', index=False)

# %%
#concatenating all june 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Jun')]
jun = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Jun/'+file)
    jun = pd.concat([jun, df])

jun

# Saving all_data to a CSV file
jun.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/JUN21.csv', index=False)

# %%
#concatenating all july 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Jul')]
jul = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Jul/'+file)
    jul = pd.concat([jul, df])

jul

# Saving all_data to a CSV file
jul.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/JUL21.csv', index=False)

# %%
#concatenating all august 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Aug')]
aug = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Aug/'+file)
    aug = pd.concat([aug, df])

aug

# Saving all_data to a CSV file
aug.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/AUG21.csv', index=False)

# %%
#concatenating all september 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Sept')]
sept = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Sept/'+file)
    sept = pd.concat([sept, df])

sept

# Saving all_data to a CSV file
sept.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/SEPT21.csv', index=False)

# %%
#concatenating all october 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Oct')]
octo = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Oct/'+file)
    octo = pd.concat([octo, df])

octo

# Saving all_data to a CSV file
octo.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/OCT21.csv', index=False)

# %%
#concatenating all november 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Nov')]
nov = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Nov/'+file)
    nov = pd.concat([nov, df])

nov

# Saving all_data to a CSV file
nov.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/NOV21.csv', index=False)

# %%
#concatenating all december 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Dec')]
dec = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021/Dec/'+file)
    dec = pd.concat([dec, df])

dec

# Saving all_data to a CSV file
dec.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/DEC21.csv', index=False)

# %%
#concatenating all april 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Apr')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Apr/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/APR20.csv', index=False)

# %%
#concatenating all may 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/May')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/May/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/MAY20.csv', index=False)

# %%
#concatenating all june 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Jun')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Jun/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/JUN20.csv', index=False)

# %%
#concatenating all july 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Jul')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Jul/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/JUL20.csv', index=False)

# %%
#concatenating all august 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Aug')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Aug/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/AUG20.csv', index=False)

# %%
#concatenating all september 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Sept')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Sept/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/SEPT20.csv', index=False)

# %%
#concatenating all october 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Oct')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Oct/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/OCT20.csv', index=False)

# %%
#concatenating all november 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Nov')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Nov/'+file)
    xx = pd.concat([xx, df])

xx
# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/NOV20.csv', index=False)

# %%
#concatenating all december 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Dec')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020/Dec/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/DEC20.csv', index=False)

# %% [markdown]
# ### Concatenating all the month-wise CSV files into one year-wise file

# %%
#concatenating all 2020 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/'+file)
    xx = pd.concat([xx, df])

xx

# Saving all_data to a CSV file
xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/2020_csv.csv', index=False)

# %%
#concatenating all 2021 files
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all')]
xx = pd.DataFrame()
for file in filenames:
    df = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/'+file)
    xx = pd.concat([xx, df])

xx

xx.to_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/2021_csv.csv', index=False)

# %% [raw]
# **We have now concatenated all the day-wise files to month-wise and to year-wise file.
# Now, we have got two file of years 2020 and 2021 on which we will be performing all analysis and comparision.**

# %% [markdown]
# ### Description of the two dataset

# %%
#Loading dataset of 2020 into pandas DataFrame
df20=pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/2020_csv.csv')
print('2020 DATA')
print("Number of rows = ",df20.shape[0])
print("Number of columns = ",df20.shape[1])
df20.head(15)
# Out:
# 2020 DATA
# Number of rows =  15330
# Number of columns =  20
#           Province_State Country_Region          Last_Update      Lat  \
# 0                Alabama             US  2020-04-12 23:18:15  32.3182
# 1                 Alaska             US  2020-04-12 23:18:15  61.3707
# 2                Arizona             US  2020-04-12 23:18:15  33.7298
# 3               Arkansas             US  2020-04-12 23:18:15  34.9697
# 4             California             US  2020-04-12 23:18:15  36.1162
# 5               Colorado             US  2020-04-12 23:18:15  39.0598
# 6            Connecticut             US  2020-04-12 23:18:15  41.5978
# 7               Delaware             US  2020-04-12 23:18:15  39.3185
# 8       Diamond Princess             US  2020-04-12 23:18:15      NaN
# 9   District of Columbia             US  2020-04-12 23:18:15  38.8974
# 10               Florida             US  2020-04-12 23:18:15  27.7663
# ...

# %%
#Describing dataset 2020
df20.info()    ##check the basic information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15330 entries, 0 to 15329
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        15330 non-null  object
#  1   Country_Region        15330 non-null  object
#  2   Last_Update           15311 non-null  object
#  3   Lat                   14784 non-null  float64
#  4   Long_                 14784 non-null  float64
#  5   Confirmed             15330 non-null  int64
#  6   Deaths                15330 non-null  int64
#  7   Recovered             12306 non-null  float64
#  8   Active                12306 non-null  float64
#  9   FIPS                  15311 non-null  float64
#  10  Incident_Rate         14784 non-null  float64
#  11  People_Tested         11816 non-null  float64
#  12  People_Hospitalized   5129 non-null   float64
#  13  Mortality_Rate        12027 non-null  float64
# ...

# %%
#Loading dataset of 2021 into pandas DataFrame
df21=pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/2021_csv.csv')
print('2021 DATA')
print("Number of rows = ",df21.shape[0])
print("Number of columns = ",df21.shape[1])
df21.head(15)
# Out:
# 2021 DATA
# Number of rows =  21170
# Number of columns =  20
#           Province_State Country_Region          Last_Update      Lat  \
# 0                Alabama             US  2021-04-02 04:30:39  32.3182
# 1                 Alaska             US  2021-04-02 04:30:39  61.3707
# 2         American Samoa             US  2021-04-02 04:30:39 -14.2710
# 3                Arizona             US  2021-04-02 04:30:39  33.7298
# 4               Arkansas             US  2021-04-02 04:30:39  34.9697
# 5             California             US  2021-04-02 07:30:30  36.1162
# 6               Colorado             US  2021-04-02 04:30:39  39.0598
# 7            Connecticut             US  2021-04-02 04:30:39  41.5978
# 8               Delaware             US  2021-04-02 04:30:39  39.3185
# 9       Diamond Princess             US  2021-04-02 04:30:39      NaN
# 10  District of Columbia             US  2021-04-02 04:30:39  38.8974
# ...

# %%
#Describing dataset 2021
df21.info()     ##check the basic information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21170 entries, 0 to 21169
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        21170 non-null  object
#  1   Country_Region        21170 non-null  object
#  2   Last_Update           21170 non-null  object
#  3   Lat                   20440 non-null  float64
#  4   Long_                 20440 non-null  float64
#  5   Confirmed             21170 non-null  int64
#  6   Deaths                21170 non-null  int64
#  7   Recovered             3008 non-null   float64
#  8   Active                3008 non-null   float64
#  9   FIPS                  21170 non-null  float64
#  10  Incident_Rate         20440 non-null  float64
#  11  Total_Test_Results    20199 non-null  float64
#  12  People_Hospitalized   0 non-null      float64
#  13  Case_Fatality_Ratio   20664 non-null  float64
# ...

# %%
#2020
df20.describe()
# Out:
#                 Lat         Long_     Confirmed        Deaths     Recovered  \
# count  14784.000000  14784.000000  1.533000e+04  15330.000000  1.230600e+04
# mean      36.840089    -85.206614  1.123347e+05   3016.449315  5.093927e+04
# std       10.789757     49.309880  1.987346e+05   5466.738695  1.092800e+05
# min      -14.271000   -170.132200  0.000000e+00      0.000000  0.000000e+00
# 25%       34.594600   -101.165775  6.840250e+03    148.000000  2.668000e+03
# 50%       39.061850    -87.944200  3.854400e+04    889.000000  1.134200e+04
# 75%       42.361650    -76.970625  1.312505e+05   3375.500000  5.518350e+04
# max       61.370700    145.673900  2.385424e+06  37799.000000  1.423001e+06
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count   12306.000000  15311.000000   14784.000000   1.181600e+04
# mean    42403.321307   3276.082424    1818.583439   1.111017e+06
# std     76803.839437  17227.157615    1904.179141   2.059628e+06
# ...

# %%
#2021
df21.describe()
# Out:
#                 Lat         Long_     Confirmed        Deaths     Recovered  \
# count  20440.000000  20440.000000  2.117000e+04  21170.000000  3.008000e+03
# mean      36.840089    -85.206614  6.202266e+05  10461.950968  2.257452e+05
# std       10.789656     49.309418  8.137378e+05  13942.468778  3.391137e+05
# min      -14.271000   -170.132000  0.000000e+00      0.000000  2.900000e+01
# 25%       34.594600   -101.165775  1.108612e+05   1581.000000  2.056900e+04
# 50%       39.061850    -87.944200  3.803100e+05   5990.000000  9.556250e+04
# 75%       42.361650    -76.970625  7.891822e+05  13021.000000  3.143600e+05
# max       61.370700    145.673900  5.519854e+06  76515.000000  2.470308e+06
#
#              Active          FIPS  Incident_Rate  Total_Test_Results  \
# count  3.008000e+03  21170.000000   20440.000000        2.019900e+04
# mean   1.272399e+05   3288.086207   10202.782408        9.000447e+06
# std    2.038473e+05  17258.033714    4334.130947        1.378262e+07
# ...

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# #### **In this part, we will look over number of rows and columns having irrelevant and null values from both year's dataset**

# %% [markdown]
# #### **This will help us in further stages where we can eliminate irrelevant rows and columns which won't be usful for us in any analysis**

# %%
#Checking for null values for 2020
temp=df20[df20.isna().any(axis=1)]
print('Looks like there are '+str(temp.shape[0])+' rows with atleast one NaN!')
print('Looks like there are '+str(df20.duplicated().sum())+' rows with duplicated values')
# Out:
# Looks like there are 15330 rows with atleast one NaN!
# Looks like there are 6 rows with duplicated values

# %%
#count of null values in each column for 2020
df20.isnull().sum(axis = 0)
# Out:
# Province_State              0
# Country_Region              0
# Last_Update                19
# Lat                       546
# Long_                     546
# Confirmed                   0
# Deaths                      0
# Recovered                3024
# Active                   3024
# FIPS                       19
# Incident_Rate             546
# People_Tested            3514
# People_Hospitalized     10201
# Mortality_Rate           3303
# UID                         0
# ISO3                        0
# Testing_Rate              546
# Hospitalization_Rate    10201
# Total_Test_Results      12362
# Case_Fatality_Ratio     12309
# dtype: int64

# %%
#count of null values in each row of 2020
df20.isnull().sum(axis = 1)
# Out:
# 0        2
# 1        0
# 2        2
# 3        0
# 4        2
#         ..
# 15325    0
# 15326    2
# 15327    0
# 15328    0
# 15329    0
# Length: 15330, dtype: int64

# %%
#count of null values in each row 2020
temp=max(df20.isnull().sum(axis = 1))
print('Maximum NaN values present in a row is : ' + str(temp))
# Out:
# maximum NaN values present in a row is : 12

# %%
df20.describe()
# Out:
#                 Lat         Long_     Confirmed        Deaths     Recovered  \
# count  14784.000000  14784.000000  1.521500e+04  15215.000000  1.229700e+04
# mean      36.840089    -85.206614  1.131833e+05   3039.238186  5.093613e+04
# std       10.789757     49.309880  1.992436e+05   5481.048750  1.093194e+05
# min      -14.271000   -170.132200  0.000000e+00      0.000000  0.000000e+00
# 25%       34.594600   -101.165775  7.126000e+03    156.500000  2.666000e+03
# 50%       39.061850    -87.944200  3.937700e+04    906.000000  1.132300e+04
# 75%       42.361650    -76.970625  1.323400e+05   3408.000000  5.517600e+04
# max       61.370700    145.673900  2.385424e+06  37799.000000  1.423001e+06
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count   12297.000000  15205.000000   14784.000000   1.181600e+04
# mean    42434.355697   2640.518711    1818.583439   1.111017e+06
# std     76823.371065  15500.915210    1904.179141   2.059628e+06
# ...

# %%
#Checking for null values for 2021
temp=df21[df21.isna().any(axis=1)]
print('Looks like there are '+str(temp.shape[0])+' rows with atleast one NaN!')
print('Looks like there are '+str(df21.duplicated().sum())+' rows with duplicated values')
# Out:
# Looks like there are 21170 rows with atleast one NaN!
# Looks like there are 0 rows with duplicated values

# %%
#count of null values in each column for 2021
df21.isnull().sum(axis = 0)
# Out:
# Province_State              0
# Country_Region              0
# Last_Update                 0
# Lat                       730
# Long_                     730
# Confirmed                   0
# Deaths                      0
# Recovered               18162
# Active                  18162
# FIPS                        0
# Incident_Rate             730
# Total_Test_Results        971
# People_Hospitalized     21170
# Case_Fatality_Ratio       506
# UID                         0
# ISO3                        0
# Testing_Rate              747
# Hospitalization_Rate    21170
# People_Tested           20946
# Mortality_Rate          20942
# dtype: int64

# %%
#count of null values in each row
temp=max(df21.isnull().sum(axis = 1))
print('maximum NaN values present in a row is : ' + str(temp))
# Out:
# maximum NaN values present in a row is : 8

# %%
df21.describe()
# Out:
#                 Lat         Long_     Confirmed        Deaths     Recovered  \
# count  20440.000000  20440.000000  2.117000e+04  21170.000000  3.008000e+03
# mean      36.840089    -85.206614  6.202266e+05  10461.950968  2.257452e+05
# std       10.789656     49.309418  8.137378e+05  13942.468778  3.391137e+05
# min      -14.271000   -170.132000  0.000000e+00      0.000000  2.900000e+01
# 25%       34.594600   -101.165775  1.108612e+05   1581.000000  2.056900e+04
# 50%       39.061850    -87.944200  3.803100e+05   5990.000000  9.556250e+04
# 75%       42.361650    -76.970625  7.891822e+05  13021.000000  3.143600e+05
# max       61.370700    145.673900  5.519854e+06  76515.000000  2.470308e+06
#
#              Active          FIPS  Incident_Rate  Total_Test_Results  \
# count  3.008000e+03  21170.000000   20440.000000        2.019900e+04
# mean   1.272399e+05   3288.086207   10202.782408        9.000447e+06
# std    2.038473e+05  17258.033714    4334.130947        1.378262e+07
# ...

# %% [markdown]
# **From the above study:**
#
# >**In 2020 year dataset, there are 15330 rows with atleast one null value and 6 rows which with repeated values. Around 4 columns have more than 10000 null values. Maximum number of null values present in a row is around 8**
#
# >**In 2021 year dataset, there are 21170 rows with atleast one null value and 6 rows which with repeated values. Around 4 columns have more than 20000 null values. Maximum number of null values present in a row is also around 8**

# %%
df20
# Out:
#       Province_State Country_Region          Last_Update      Lat     Long_  \
# 0            Alabama             US  2020-04-12 23:18:15  32.3182  -86.9023
# 1             Alaska             US  2020-04-12 23:18:15  61.3707 -152.4044
# 2            Arizona             US  2020-04-12 23:18:15  33.7298 -111.4312
# 3           Arkansas             US  2020-04-12 23:18:15  34.9697  -92.3731
# 4         California             US  2020-04-12 23:18:15  36.1162 -119.6816
# ...              ...            ...                  ...      ...       ...
# 15325       Virginia             US  2020-10-01 04:30:28  37.7693  -78.1700
# 15326     Washington             US  2020-10-01 04:30:28  47.4009 -121.4905
# 15327  West Virginia             US  2020-10-01 04:30:28  38.4912  -80.9545
# 15328      Wisconsin             US  2020-10-01 04:30:28  44.2685  -89.6165
# 15329        Wyoming             US  2020-10-01 04:30:28  42.7560 -107.3025
#
# ...

# %%
df21
# Out:
#        Province_State Country_Region          Last_Update      Lat     Long_  \
# 0             Alabama             US  2021-04-02 04:30:39  32.3182  -86.9023
# 1              Alaska             US  2021-04-02 04:30:39  61.3707 -152.4044
# 2      American Samoa             US  2021-04-02 04:30:39 -14.2710 -170.1320
# 3             Arizona             US  2021-04-02 04:30:39  33.7298 -111.4312
# 4            Arkansas             US  2021-04-02 04:30:39  34.9697  -92.3731
# ...               ...            ...                  ...      ...       ...
# 21165        Virginia             US  2021-10-01 04:31:22  37.7693  -78.1700
# 21166      Washington             US  2021-10-01 04:31:22  47.4009 -121.4905
# 21167   West Virginia             US  2021-10-01 04:31:22  38.4912  -80.9545
# 21168       Wisconsin             US  2021-10-01 04:31:22  44.2685  -89.6165
# 21169         Wyoming             US  2021-10-01 04:31:22  42.7560 -107.3025
#
# ...

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# **This part will be consisting of monthly and yearly analysis of the two year dataset with pictorial representation in terms of graphs**

# %%
#grouping with respect to counties in the year 2021 dataset
results=df20.groupby('Province_State').sum()
results
# Out:
#                                  Lat       Long_  Confirmed   Deaths  \
# Province_State
# Alabama                    8532.0048 -22942.2072   32265623   525695
# Alaska                    16201.8648 -40234.7616    2780257    14080
# American Samoa            -3767.5440 -44914.8482          0        0
# Arizona                    8904.6672 -29417.8368   47038197  1047218
# Arkansas                   9232.0008 -24386.4984   18385562   285637
# California                 9534.6768 -31595.9424  177397071  3033930
# Colorado                  10311.7872 -27802.1304   23249667   537037
# Connecticut               10981.8192 -19207.4256   17121029  1116769
# Delaware                  10380.0840 -19933.8744    5142855   159553
# Diamond Princess              0.0000      0.0000      12936        0
# District of Columbia      10268.9136 -20335.0752    3628461   146076
# Florida                    7330.3032 -21565.3152  137941068  2629026
# ...

# %%
#grouping with respect to counties in the year 2021 dataset
results1=df21.groupby('Province_State').sum()
results1
# Out:
#                                  Lat       Long_   Confirmed    Deaths  \
# Province_State
# Alabama                   11796.1430 -31719.3395   225503110   4290163
# Alaska                    22400.3055 -55627.6060    31861667    167670
# American Samoa            -5208.9150 -62098.1800         491         0
# Arizona                   12311.3770 -40672.3880   347146112   6534495
# Arkansas                  12763.9405 -33716.1815   143228353   2343067
# California                13182.4130 -43683.7840  1493617145  22116256
# Colorado                  14256.8270 -38438.5515   209980290   2541168
# Connecticut               15183.1970 -26555.7210   125627476   2960998
# Delaware                  14351.2525 -27560.0915    41117061    629641
# Diamond Princess              0.0000      0.0000       17885         0
# District of Columbia      14197.5510 -28114.7820    18800085    401166
# Florida                   10134.6995 -29815.6820   970161756  15197260
# ...

# %%
plot1=results1.nlargest(20,'Deaths',keep='first')
#plot2=results1.nlargest(20,'Deaths',keep='first')
plot1.head(20)
#plot2.head(20)
plt.figure(figsize=(5,10))
sns.barplot(y=plot1['Deaths'],x=plot1.index,data=plot1)
#sns.barplot(y=plot2['Deaths'],x=plot2.index,data=plot2)
plt.title("Max deaths vs State")
plt.ylabel("Deaths")
plt.xlabel("State") 
plot1['Delivery_Time(in min)'],plot1.index=plt.xticks()
plt.setp(plot1.index,rotation=90)
plt.grid(axis='y')
print("Maximum Deaths were taken place in California in the year 2021 of counts 22116251")
# Out:
# Maximum Deaths were taken place in California in the year 2021 of counts 22116251

# %% [markdown]
# # Analysis
# >**This above graph shows maximum number of deaths taken place of first 20 states in the year 2021. The bars are arranged according to state having highest number of deaths that is California**
#
# >**With this, we can say that the states with more population are affected with the COVID disease resulting in the more count in death**

# %%
plot1=results.nlargest(20,'Deaths',keep='first')

plot1.head(20)

plt.figure(figsize=(5,10))
sns.barplot(y=plot1['Deaths'],x=plot1.index,data=plot1)

plt.title("Max deaths vs State")
plt.ylabel("Deaths")
plt.xlabel("State") 
plot1['Deaths'],plot1.index=plt.xticks()
plt.setp(plot1.index,rotation=90)
plt.grid(axis='y')
de = plot1['Deaths'].max()
print("Maximum Deaths were taken place in NewYork in the year 2020 with counts 8284627")
# Out:
# Maximum Deaths were taken place in NewYork in the year 2020 with counts 8284627

# %% [markdown]
# # Analysis
# >**This above graph shows maximum number of deaths taken place of first 20 states in the year 2020. The bars are arranged according to state having highest number of deaths that is New York**
#
# >**With this, we can say that the states with more population are affected with the COVID disease resulting in the more count in death**

# %%
plot1=results.nlargest(20,'Deaths',keep='first')
plot2=results1.nlargest(20,'Deaths',keep='first')
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
#plt.figure(figsize=(15,40))
ax1.bar(plot1.index, plot1['Deaths'], color='darkmagenta')
ax1.set_xticklabels(results.index, rotation='vertical', size=10)
ax1.set_ylabel(' DEATHS IN THE YEAR 2020 ', color='darkmagenta')
ax1.set_xlabel('STATES')

ax2.plot(plot2.index, plot2['Deaths'], color='grey', linewidth=2, marker='o', markerfacecolor='y',linestyle='--')
ax2.set_ylabel('DEATHS IN THE YEAR 2021', color='grey')
plt.show()
print("We can observe deaths are more in the year 2021")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_22736/1665567028.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(results.index, rotation='vertical', size=10)
# We can observe deaths are comparatively more in the year 2021

# %% [markdown]
# # Comparision Analysis
# >**By comparing 2020 and 2021 graph, we can say that number of deaths in both year's are nearly equal. As the count indicates year 2021 were more than 2020. One of the main reason might be as COVID started to affect in mid 2020 and incresed till 2021 end resulting in more months data from 2021 than in 2020**

# %%
plot1=results.nlargest(15,'Deaths',keep='first')
plot1
# Out:
#                        Lat       Long_  Confirmed   Deaths    Recovered  \
# Province_State
# New York        11131.7448 -19786.2984  123786141  8284627   19064446.0
# New Jersey      10638.9096 -19673.5440   58995598  3804455    8429532.0
# California       9534.6768 -31595.9424  177397071  3033930          0.0
# Texas            8198.3880 -25756.7640  156953703  2964759  123565589.0
# Florida          7330.3032 -21565.3152  137941068  2629026          0.0
# Illinois        10652.2680 -23492.3304   81698621  2197033          0.0
# Massachusetts   11148.7728 -18883.9464   37231133  2048963   23042376.0
# Pennsylvania    10715.9712 -20383.3872   47199270  1986193   30762504.0
# Michigan        11438.2224 -22317.5304   41919609  1827565   23620880.0
# Georgia          8722.7184 -22081.7784   64458775  1393722          0.0
# Louisiana        8228.7480 -24253.0992   34746821  1177072   28514424.0
# Ohio            10662.6432 -21849.9336   44823090  1147479   31507780.0
# ...

# %% [markdown]
# #### Month-wise number of deaths in the year 2021

# %%
#temp = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/FEB21.csv')
#feb=temp['Deaths'].max()

deaths_2021 = []
recovered_2021 = []
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all')]

for file in filenames:
    temp = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/'+file)
    store=temp['Deaths'].max()
    store1=temp['Recovered'].max()
    deaths_2021.append(store)
    recovered_2021.append(store1)

temp1 = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2021_csv_all/DEC21.csv')
dec1=temp1['Deaths'].max()
deaths_2021
filenames
MONTHS=['APR','AUG','DEC','FEB','JAN','JUL','JUN','MAR','MAY','NOV','OCT','SEPT']
deaths_2021
# Out:
# [60680,
#  65197,
#  76515,
#  51993,
#  43450,
#  64003,
#  63154,
#  58119,
#  62115,
#  74471,
#  71948,
#  68810]

# %%
MAX_DEATH = deaths_2021
fig = plt.figure(figsize = (10,5))

plt.bar( MONTHS,MAX_DEATH, color ='maroon', width = 0.5)
plt.xticks(MONTHS)
plt.ylabel("MAXIMUM DEATHS IN THE YEAR 21'")
plt.xlabel("MONTHS 21'")

plt.show()
print("Maximum Deaths were taken place in DECEMBER"+ ": " + str(dec1))
# Out:
# Maximum Deaths were taken place in DECEMBER: 76515

# %% [markdown]
# #### Analysis
# >**The above graph shows that number of deaths were most in the month of December and least in the month of January.**
#
# >**In general, number of deaths are almost similar in all the months, that is, there no much of highs or lows in any of the months in the year 2021**

# %% [markdown]
# #### Month-wise number of deaths in the year 2020

# %%
deaths_2020 = []
recovered_2020=[]
filenames = [file for file in os.listdir('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all')]

for file in filenames:
    temp = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/'+file)
    store=temp['Deaths'].max()
    store1=temp['Recovered'].max()
    deaths_2020.append(store)
    recovered_2020.append(store1)

temp = pd.read_csv('C:/Users/LENOVO/Downloads/EDA COURSE PROJECT/2020_csv_all/DEC20.csv')
dec=temp['Deaths'].max()

deaths_2020
filenames
# Out:
# ['APR20.csv',
#  'AUG20.csv',
#  'DEC20.csv',
#  'JUL20.csv',
#  'JUN20.csv',
#  'MAY20.csv',
#  'NOV20.csv',
#  'OCT20.csv',
#  'SEPT20.csv']

# %%
MAX_DEATH = deaths_2020
MAX_RECOVERED = recovered_2020
MONTHS=['APR','AUG','DEC','JUL','JUN','MAY','NOV','OCT','SEPT']
fig = plt.figure(figsize = (10,5))

plt.bar( MONTHS,MAX_DEATH, color ='m', width = 0.5)
plt.xticks(MONTHS)
plt.ylabel("MAXIMUM DEATHS IN THE YEAR 20'")
plt.xlabel("MONTHS 20'")

plt.show()
print("Maximum Deaths were taken place in DECEMBER"+ ": " + str(dec))
# Out:
# Maximum Deaths were taken place in DECEMBER: 37799

# %% [markdown]
# #### Analysis
# >**The above graph shows that number of deaths were most in the month of December and least in the month of April. There is no data from the month January to March as COVID started to affect from april of 2020. As April was the starting, it has the least deaths as COVID was about to increase from then!**
#
# >**Here also, number of deaths are almost similar in all the months, that is, there no much of highs or lows in any of the months in the year 2020**

# %% [markdown]
# #### Deaths and recovered in the year 2020

# %%
fig = plt.figure(figsize = (10,5))
MONTHS=['APR','AUG','DEC','JUL','JUN','MAY','NOV','OCT','SEPT']
MAX_DEATH = deaths_2020
MAX_RECOVERED = recovered_2020
  
X_axis = np.arange(len(MONTHS))
  
plt.bar(X_axis - 0.2, MAX_DEATH, 0.4, label = 'D',color='k')
plt.bar(X_axis + 0.2, MAX_RECOVERED, 0.4, label = 'R',color='maroon')
  
plt.xticks(X_axis, MONTHS)
plt.xlabel("D->DEATH, R->RECOVERED")
plt.ylabel("COUNTS")
plt.title("COMPARISON BETWEEN DEATHS AND RECOVERED IN THE YEAR 20'")
plt.legend()
plt.show()

#max dec : analysis

# %% [markdown]
# #### ANALYSIS:
# >**In the year 2020, death counts are comparatively less as it was starting phase of covid 19, and most of people were immunitevely strong.**
#
# >**Also during early phase of pandemic equipments for treatment like CPU, beds, oxygen cyclinders and other medicinal drugs were sufficient.**
#
# >**Number of deaths are high than recovered in every month as there was no cure or vaccination**
